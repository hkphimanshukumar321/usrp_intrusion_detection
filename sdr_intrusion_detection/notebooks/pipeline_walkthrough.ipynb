# %% [markdown]
# # SDR Intrusion Detection Walkthrough
# This notebook demonstrates the two paths for the project: utilizing the Pure Python Simulation engine versus running raw GNURadio Hardware collections.

# %% [markdown]
# ## Case 1: Pure-Python Simulation
# We can artificially generate the fading parameters mimicking human/drone bodies crossing a signal path, extract features, and train the Custom DenseNet models directly via terminal arguments:

# %%
# !python -m src.sim_system --duration 5.0
# !python -m src.train --model custom_densenet

# %% [markdown]
# ## Case 2: GNU Radio Simulator (Hardware Collection)
# If utilizing the Physical flowgraph sdr_flowgraphs/usrp_data_collector.grc, your generated .dat dataset arrays will be dropped into /dataset/.
#
# You can skip the simulator generation phase entirely and proceed straight to inference evaluation over your real life datasets using --skip_data.

# %%
# !python -m src.run_ablation --skip_data
